# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
recent_grads=pd.read_csv("recent-grads.csv")
#be familiar with how data is structured
recent_grads.iloc[0]# show title and first row
recent_grads.head()
recent_grads.tail()
recent_grads.shape
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count=len(recent_grads) #173
recent_grads=recent_grads.dropna()
cleaned_data_count=len(recent_grads) #172
# Out:
# 172 172

# %%
recent_grads.plot(x='Sample_size',y="Median",kind="scatter",title="relationship between Sample_size and Median")

# %%
recent_grads.plot(x='Sample_size',y="Unemployment_rate",kind="scatter",title="relationship between Sample_size and Unemployment_rate")

# %%
recent_grads.plot(x='Full_time',y="Median",kind="scatter",title="relationship between Full_time and Median")

# %%
recent_grads.plot(x='ShareWomen',y="Unemployment_rate",kind="scatter",title="relationship between ShareWomen and Unemployment_rate")

# %%
recent_grads.plot(x='Men',y="Median",kind="scatter",title="relationship between Men and Median")

# %%
recent_grads.plot(x='Women',y="Median",kind="scatter",title="relationship between Women and Median")

# %% [markdown]
# 1. Do students in more popular majors make more money?
# No, from the first plot, it shows that the larger sample size doesn't gaurantee the high median income
#
# 2. Do students that majored in subjects that were majority female make more money?
# No, actually it shows less money
#
# 3. Is there any link between the number of full-time employees and median salary?
# The more full-time employees there are, the less likely to earn high salary.

# %%
recent_grads["Sample_size"].hist(bins=20)

# %%
recent_grads["Median"].hist(bins=20)

# %%
recent_grads["Employed"].hist(bins=20)

# %%
recent_grads["Full_time"].hist(bins=20)

# %%
recent_grads["ShareWomen"].hist(bins=20)

# %%
recent_grads["Unemployment_rate"].hist(bins=20)

# %%
recent_grads["Men"].hist(bins=20)

# %%
recent_grads["Women"].hist(bins=20)

# %% [markdown]
# 1. What percent of majors are predominantly male? Predominantly female? It's hard to tell from the chart, I would say male is 55% and female is 45%
#
# 2. What's the most common median salary range?33000-35000

# %%
# create scatter matrix plot
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9782652ac8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f978246d630>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[recent_grads.shape[0]-10:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[recent_grads.shape[0]-10:].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[:10].plot.bar(x='Major', y=['Men','Women'], stacked=True)
recent_grads[recent_grads.shape[0]-10:].plot.bar(x='Major', y=['Men','Women'], stacked=True)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
recent_grads.plot.box(y="Median")
recent_grads.plot.box(y="Unemployment_rate")
